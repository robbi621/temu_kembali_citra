# %% [markdown]
# <a href="https://colab.research.google.com/github/robbi621/temu_kembali_citra/blob/main/opencv_basic/arithmetic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  0B6904A1-A7C3-46F8-A1DC-94D57735CDC0.png
# '126409_18900_Format Laporan Praktikum.docx'
# '126409_18900_Format Laporan Praktikum.gdoc'
#  18D7648C-AAAF-43FC-939D-4D165B35CCC9.png
#  1909.03975.gdoc
#  1909.03975.pdf
#  1C3AAED1-9D9D-4821-9910-039E16CEDB87.png
# '201810370311036-robbi adam.pdf'
#  20210605-173655-768.mp4
#  20210613-195248-010.mp4
#  2103.00266.gdoc
#  2103.00266.pdf
#  2106.12569.gdoc
#  2106.12569.pdf
#  2107.03820.gdoc
#  2107.03820.pdf
# '2107.11611 - Copy.gdoc'
# '2107.11611 - Copy.pdf'
# '2107.11737 - Copy.gdoc'
# '2107.11737 - Copy.pdf'
#  322226F3-B689-4BE7-A3DB-3B1B7C8FD252.png
# '3 PERNIKAHAN.ppt'
#  45546B78-3C3D-4530-953D-BAF4734F89E5.png
#  49171ECE-816D-43D9-941F-67F83BB32EC1.png
#  578ECA80-017F-4269-A6FC-2EA30D6067D7.png
#  70094E0A-EE90-40D1-95F7-69F8E9A6B83E.png
#  742C62AA-6D31-4616-9D68-FF568EBC2E5A.png
#  9E0E776D-A5FA-4D9D-8E65-FB0C0AF7E267.png
# 'ABDI ZAKI_A_UAS'/
# 'AIK tugas 1 robbi adam raditya 2018-036.docx'
# 'akhlak dalam keluarga_2018-036.pdf'
# 'akhlak dalam keluarga 2 _2018-036.pdf'
# 'akhlak dan muamalah_2018-036.pdf'
# 'akhlak sosial_2018-036.pdf'
# 'Antimicrobial Agents and Chemotherapy-2003-Rougier-1010.full.gdoc'
# 'Antimicrobial Agents and Chemotherapy-2003-Rougier-1010.full.pdf'
# 'archive (3).zip'
# 'B_201810370311036 (1).pdf'
#  B_201810370311036.pdf
# 'B-201810370311036-Robbi Adam.pdf'
# 'B-201810370311036-Robbi Adam Raditya.pdf'
#  bedengan/
# 'budug asu'/
#  cangar/
#  CCA6360E-21C6-4FFA-8133-CBF6EF78A7AC.png
#  Classroom/
# 'Colab Notebooks'/
#  data_sample2.csv
#  data_sample.csv
#  data.xls
# 'Dokumen tanpa judul.gdoc'
# 'E-Certificate <Nama Lengkap>> Webinar Kuliah Praktisi (1).pdf'
# 'E-Certificate <Nama Lengkap>> Webinar Kuliah Praktisi.pdf'
# 'E-Certificate _Nama Lengkap__ Webinar Kuliah Praktisi.pdf'
#  ED6BEF99-492F-4CA7-89E8-903E8021D59E.png
#  F473114B-CD07-47AA-ADA6-FAC9D88F12CA.png
#  FE28068B-A64E-4334-9E0A-03CB596CF3BA.png
#  FlowerColorImages.h5
# 'Getting started.pdf'
#  healthcare-dataset-stroke-data.gsheet
#  IMG_3268.MOV
#  Intent.json
# 'islam dan umat beragama_2018-036.pdf'
# 'jarkom 5E-201810370311036-robbi adam (1).rar'
# 'jarkom 5E-201810370311036-robbi adam.rar'
# 'jarkom 5E-201810370311036-robbi.rar'
#  Kegiatan/
#  Kegiatan_Modul_3-1-1.ipynb
# 'Kegiatan Modul 3.ipynb'
# 'Kegiatan_Modul_5_v2 (1).ipynb'
# 'kelas B- 201810370311036.pdf'
# 'kelas B-201810370311036.pdf'
# 'KELAS B - 201810370311036.pdf'
# 'Materi Modul 3 - Data Preprocessing.ipynb'
# 'Meet Recordings'/
# 'Modeling and simulation of a wirelessly-powered thermopneumatic micropump for drug delivery applications.gdoc'
# 'Modeling and simulation of a wirelessly-powered thermopneumatic micropump for drug delivery applications.pdf'
# 'MODELING, SIMULATION AND MODEL OPTIMIZATION OF.gdoc'
# 'MODELING, SIMULATION AND MODEL OPTIMIZATION OF.pdf'
# 'MODUL_1_PC_robbi adam_036.mp4'
# 'pantai tanpa nama'/
# 'PHYTON - PTI.ipynb'
# 'Quiz_AIK_201810370311036_Robbi adam raditya.pdf'
#  Robbi/
#  robbi_adam_2018-036.ppt
# 'robbi adam raditya_2018-036 tugas pemodelan'/
# 'robbi adam raditya_201810370311036.js'
# 'robbi adam raditya 201810370311036.mp4'
# 'Robbi adam raditya_UTS_PenKom_2018-036.pdf'
# 'Salinan dari KKB - BAGIAN 6.pdf'
# 'Salinan dari STRUKTUR ORGANISASI BAWASLU KOTA MALANG 2021 .pdf'
# 'Screenshot (11).png'
# 'Screenshot (15).png'
# 'Screenshot (2).png'
# 'SIMULATION MODEL FOR RATIONAL UNIFIED PROCESS (RUP) SOFTWARE.pdf'
# 'System Dynamics Simulation Model to Increase Paddy (1).gdoc'
# 'System Dynamics Simulation Model to Increase Paddy.gdoc'
# 'System Dynamics Simulation Model to Increase Paddy.pdf'
# 'The 4Ws of Problem Scoping - Template.gdoc'
#  TKC/
# 'Translated copy of 1909.03975.gdoc'
# 'Translated copy of 2103.00266.gdoc'
# 'Translated copy of 2106.12569.gdoc'
# 'Translated copy of 2107.03820.gdoc'
# 'Translated copy of 2107.11611 - Copy.gdoc'
# 'Translated copy of 2107.11737 - Copy.gdoc'
# 'Translated copy of Antimicrobial Agents and Chemotherapy-2003-Rougier-1010 (1).full.gdoc'
# 'Translated copy of Antimicrobial Agents and Chemotherapy-2003-Rougier-1010.full.gdoc'
# 'Translated copy of Modeling and simulation of a wirelessly-powered thermopneumatic micropump for drug delivery applications.gdoc'
# 'Translated copy of MODELING, SIMULATION AND MODEL OPTIMIZATION OF.gdoc'
# 'Translated copy of System Dynamics Simulation Model to Increase Paddy.gdoc'
# 'Translated copy of Translated copy of 2107.11611 - Copy.gdoc'
# 'tugas NLP'/
#  tugas-NLP.ipynb
# 'uas pem web (036).pdf'
# 'UAS PSD'/
#  Untitled.png
#  whatsapp.gsheet
#  zoom_0.mp4

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "/content/drive/MyDrive/TKC/00_002.png"
}

# %%
# images are NumPy arrays stored as unsigned 8-bit integers (unit8)
# with values in the range [0, 255]; when using the add/subtract
# functions in OpenCV, these values will be *clipped* to this range,
# even if they fall outside the range [0, 255] after applying the
# operation
added = cv2.add(np.uint8([200]), np.uint8([100]))
subtracted = cv2.subtract(np.uint8([50]), np.uint8([100]))
print("max of 255: {}".format(added))
print("min of 0: {}".format(subtracted))
# Out:
# max of 255: [[255]]
# min of 0: [[0]]

# %%
# using NumPy arithmetic operations (rather than OpenCV operations)
# will result in a modulo ("wrap around") instead of being clipped
# to the range [0, 255]
added = np.uint8([200]) + np.uint8([100])
subtracted = np.uint8([50]) - np.uint8([100])
print("wrap around: {}".format(added))
print("wrap around: {}".format(subtracted))
# Out:
# wrap around: [44]
# wrap around: [206]

# %%
# load the original input image and display it to our screen
image = cv2.imread(args["image"])
plt_imshow("Original", image)

# %%
# increasing the pixel intensities in our input image by 100 is
# accomplished by constructing a NumPy array that has the *same
# dimensions* as our input image, filling it with ones, multiplying
# it by 100, and then adding the input image and matrix together
M = np.ones(image.shape, dtype="uint8") * 100
added = cv2.add(image, M)
plt_imshow("Lighter", added)

# %%
# similarly, we can subtract 50 from all pixels in our image and make it
# darker
M = np.ones(image.shape, dtype="uint8") * 50
subtracted = cv2.subtract(image, M)
plt_imshow("Darker", subtracted)
